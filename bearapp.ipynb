# %%
conda install pytorch==1.6.0 torchvision==0.7.0 -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# done
# Solving environment: /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# done
# Solving environment: /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining prometheus_client:   1%|▏             | 2/210 [00:00<00:41,  5.02it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining typing_extensions:   2%|▎             | 5/210 [00:01<01:42,  2.01it/s]
# -
# Examining chardet:   3%|▋                       | 6/210 [00:02<01:20,  2.54it/s]
# Examining scipy:   3%|▊                         | 7/210 [00:02<01:20,  2.54it/s]
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining scikit-learn:   4%|▊                  | 9/210 [00:05<02:13,  1.51it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining spacy:   5%|█▏                       | 10/210 [00:11<06:48,  2.04s/it]
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining nbconvert:   5%|█                    | 11/210 [00:12<06:21,  1.92s/it]
# \
# |
# /
# -
# \
# |
# Examining jinja2:   6%|█▎                      | 12/210 [00:13<05:02,  1.53s/it]
# /
# -
# \
# |
# Examining pyopenssl:   6%|█▎                   | 13/210 [00:14<04:00,  1.22s/it]
# /
# -
# \
# Examining jedi:   7%|█▊                        | 15/210 [00:14<02:57,  1.10it/s]
# |
# /
# -
# Examining prompt_toolkit:   8%|█▏              | 16/210 [00:14<02:21,  1.37it/s]
# \
# |
# /
# Examining testpath:   8%|█▊                    | 17/210 [00:14<01:54,  1.68it/s]
# -
# Examining defusedxml:   9%|█▊                  | 19/210 [00:15<01:23,  2.30it/s]
# \
# |
# Examining ipython:  10%|██▍                    | 22/210 [00:15<00:50,  3.76it/s]
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining numpy:  11%|██▊                      | 24/210 [00:16<01:08,  2.73it/s]
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining packaging:  14%|██▉                  | 29/210 [00:19<03:35,  1.19s/it]
# -
# \
# |
# Examining gobject-introspection:  15%|█▎       | 32/210 [00:20<02:30,  1.18it/s]
# /
# -
# Examining murmurhash:  16%|███▏                | 34/210 [00:20<01:48,  1.62it/s]
# \
# Examining urllib3:  18%|████                   | 37/210 [00:20<01:47,  1.62it/s]
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining pexpect:  19%|████▎                  | 39/210 [00:21<01:25,  2.00it/s]
# /
# Examining libtiff:  23%|█████▎                 | 48/210 [00:21<01:03,  2.54it/s]
# Examining decorator:  24%|█████                | 50/210 [00:21<01:03,  2.54it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining backcall:  28%|██████▏               | 59/210 [00:23<00:32,  4.66it/s]
# |
# Examining python-dateutil:  30%|████▍          | 62/210 [00:23<00:24,  6.03it/s]
# /
# Examining krb5:  30%|███████▉                  | 64/210 [00:23<00:19,  7.49it/s]
# Examining importlib-metadata:  32%|███▊        | 67/210 [00:23<00:19,  7.49it/s]
# Examining ipython_genutils:  33%|████▌         | 69/210 [00:23<00:14,  9.75it/s]
# |
# /
# Examining requests:  35%|███████▋              | 73/210 [00:23<00:12, 11.09it/s]
# -
# \
# |
# Examining setuptools:  36%|███████▏            | 75/210 [00:23<00:15,  8.88it/s]
# /
# -
# \
# |
# /
# -
# \
# |
# Examining cymem:  38%|█████████▌               | 80/210 [00:24<00:26,  4.84it/s]
# Examining catalogue:  39%|████████             | 81/210 [00:24<00:26,  4.84it/s]
# /
# Examining backports:  40%|████████▎            | 83/210 [00:25<00:19,  6.47it/s]
# Examining jupyter_client:  40%|██████▍         | 85/210 [00:25<00:15,  7.91it/s]
# |
# /
# -
# \
# Examining brotlipy:  40%|████████▉             | 85/210 [00:25<00:15,  7.91it/s]
# /
# -
# Examining pip:  42%|███████████▍               | 89/210 [00:26<00:19,  6.08it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining preshed:  43%|█████████▉             | 91/210 [00:27<00:37,  3.18it/s]
# |
# Examining jupyter_console:  44%|██████▌        | 92/210 [00:27<00:31,  3.75it/s]
# /
# -
# \
# |
# /
# Examining jupyterlab_pygments:  44%|████▊      | 93/210 [00:28<00:39,  2.95it/s]
# Examining srsly:  47%|███████████▋             | 98/210 [00:28<00:37,  2.95it/s]
# Examining six:  48%|████████████▍             | 100/210 [00:28<00:27,  4.06it/s]
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining entrypoints:  49%|████████▋         | 102/210 [00:30<00:45,  2.39it/s]
# Examining ptyprocess:  50%|█████████▍         | 104/210 [00:30<00:34,  3.07it/s]
# /
# Examining qtconsole:  51%|██████████▏         | 107/210 [00:30<00:25,  4.11it/s]
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining prompt-toolkit:  52%|███████▊       | 109/210 [00:31<00:27,  3.63it/s]
# |
# /
# Examining pandas:  53%|████████████▏          | 111/210 [00:31<00:22,  4.47it/s]
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining pyrsistent:  54%|██████████▏        | 113/210 [00:34<01:02,  1.54it/s]
# /
# -
# \
# |
# Examining traitlets:  55%|███████████         | 116/210 [00:35<00:41,  2.24it/s]
# -
# Examining torchvision==0.7.0:  56%|██████▏    | 118/210 [00:35<00:30,  3.03it/s]
# \
# |
# /
# -
# \
# Examining pickleshare:  57%|██████████▏       | 119/210 [00:35<00:38,  2.39it/s]
# /
# -
# Examining libxcb:  58%|█████████████▎         | 122/210 [00:36<00:29,  2.98it/s]
# Examining qtpy:  59%|██████████████▋          | 123/210 [00:36<00:29,  2.98it/s]
# |
# /
# Examining wcwidth:  60%|█████████████         | 125/210 [00:36<00:22,  3.84it/s]
# \
# |
# Examining libwebp-base:  60%|██████████▎      | 127/210 [00:36<00:17,  4.85it/s]
# Examining pandocfilters:  61%|█████████▊      | 128/210 [00:36<00:16,  4.89it/s]
# Examining nest-asyncio:  61%|██████████▍      | 129/210 [00:37<00:16,  4.89it/s]
# \
# |
# /
# -
# \
# |
# Examining graphviz:  65%|█████████████▋       | 137/210 [00:37<00:09,  7.31it/s]
# Examining harfbuzz:  66%|█████████████▉       | 139/210 [00:37<00:08,  8.33it/s]
# Examining plac:  68%|████████████████▉        | 142/210 [00:37<00:08,  8.33it/s]
# -
# \
# Examining pytorch==1.6.0:  69%|██████████▎    | 144/210 [00:38<00:06, 10.15it/s]
# |
# /
# -
# \
# Examining wasabi:  70%|███████████████▉       | 146/210 [00:38<00:09,  6.86it/s]
# Examining send2trash:  70%|█████████████▏     | 146/210 [00:38<00:09,  6.86it/s]
# Examining cython-blis:  70%|████████████▋     | 148/210 [00:38<00:08,  7.35it/s]
# \
# |
# Examining pytz:  71%|█████████████████▊       | 150/210 [00:39<00:07,  7.83it/s]
# /
# -
# Examining pyzmq:  72%|█████████████████▎      | 152/210 [00:39<00:07,  7.55it/s]
# \
# |
# Examining markupsafe:  73%|█████████████▉     | 154/210 [00:39<00:07,  7.84it/s]
# Examining ipywidgets:  74%|██████████████     | 155/210 [00:39<00:06,  8.33it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining pyqt:  74%|██████████████████▌      | 156/210 [00:41<00:31,  1.69it/s]
# \
# Examining qt:  76%|████████████████████▌      | 160/210 [00:41<00:23,  2.15it/s]
# Examining bleach:  77%|█████████████████▋     | 161/210 [00:41<00:22,  2.15it/s]
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining matplotlib-base:  80%|███████████▏  | 168/210 [00:48<00:57,  1.37s/it]
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining cffi:  81%|████████████████████▏    | 170/210 [00:49<00:45,  1.13s/it]
# /
# -
# Examining idna:  82%|████████████████████▍    | 172/210 [00:50<00:32,  1.18it/s]
# |
# /
# Examining webencodings:  84%|██████████████▎  | 177/210 [00:50<00:21,  1.55it/s]
# Examining thinc:  85%|████████████████████▍   | 179/210 [00:50<00:14,  2.18it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining fastai:  86%|███████████████████▊   | 181/210 [00:52<00:18,  1.57it/s]
# \
# Examining nbclient:  87%|██████████████████▎  | 183/210 [00:52<00:12,  2.14it/s]
# Examining pygments:  88%|██████████████████▍  | 184/210 [00:52<00:12,  2.14it/s]
# /
# -
# \
# Examining async_generator:  89%|████████████▍ | 186/210 [00:53<00:09,  2.64it/s]
# /
# Examining joblib:  90%|████████████████████▋  | 189/210 [00:53<00:05,  3.56it/s]
# -
# \
# Examining pyyaml:  91%|█████████████████████  | 192/210 [00:53<00:04,  4.16it/s]
# /
# Examining nbformat:  93%|███████████████████▌ | 195/210 [00:53<00:02,  5.33it/s]
# \
# |
# Examining argon2-cffi:  94%|████████████████▉ | 197/210 [00:54<00:02,  6.14it/s]
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining wheel:  97%|███████████████████████▎| 204/210 [00:55<00:01,  4.78it/s]
# \
# |
# /
# -
# \
# Examining tornado:  98%|█████████████████████▌| 206/210 [00:56<00:00,  4.16it/s]
# /
# -
# Examining jupyter:  99%|█████████████████████▋| 207/210 [00:56<00:00,  4.23it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining cryptography:  99%|████████████████▊| 208/210 [00:57<00:00,  2.10it/s]
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining dbus: 100%|████████████████████████▉| 209/210 [00:58<00:00,  1.60it/s]
# Examining conflict for jsonschema notebook ipywidgets spacy nbconvert nbformat f
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for jsonschema pandas markupsafe pyzmq ipywidgets pyqt pyrsis
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for jsonschema srsly importlib-metadata spacy ipykernel thinc
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for jsonschema spacy nbformat fastai matplotlib:   6%| | 13/2
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for jsonschema ipywidgets python scikit-learn spacy nbconvert
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for jsonschema certifi spacy jinja2 bleach terminado matplotl
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for jsonschema pandas ipywidgets pyrsistent scipy scikit-lear
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for jsonschema notebook jupyter_console ipywidgets importlib-
# |
# /
# -
# \
# |
# /
# Examining conflict for jsonschema yaml prometheus_client widgetsnbextension typi
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for jsonschema srsly spacy ipykernel thinc catalogue nbformat
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for jsonschema nbconvert catalogue entrypoints importlib_meta
# \
# |
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for jsonschema spacy pyrsistent nbformat:  11%| | 23/210 [02:
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for jsonschema prometheus_client typing_extensions nbconvert
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for jsonschema prometheus_client widgetsnbextension chardet t
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for jsonschema decorator prometheus_client ipywidgets typing_
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for jsonschema importlib_metadata catalogue:  15%|▏| 31/210 [
# Examining conflict for yaml pyyaml fastai:  15%|▏| 31/210 [03:05<12:25,  4.17s/i
# |
# Examining conflict for yaml xorg-libxext scipy scikit-learn spacy fontconfig bla
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for yaml xorg-libxext scipy scikit-learn spacy fontconfig bla
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for notebook widgetsnbextension prometheus_client jupyter:  1
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for notebook prometheus_client:  19%|▏| 39/210 [03:29<07:08,
# \
# Examining conflict for prometheus_client pyopenssl urllib3 requests:  20%|▏| 41/
# Examining conflict for widgetsnbextension jupyter ipywidgets:  20%|▏| 41/210 [03
# /
# -
# \
# |
# Examining conflict for notebook widgetsnbextension send2trash jupyter:  21%|▏| 4
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for notebook jupyter_console pyzmq widgetsnbextension ipykern
# \
# |
# /
# -
# \
# Examining conflict for notebook ipywidgets widgetsnbextension nbconvert nbformat
# /
# -
# Examining conflict for notebook widgetsnbextension jupyter ipywidgets:  23%|▏| 4
# Examining conflict for notebook jupyter_console matplotlib-base ipywidgets widge
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for notebook jupyter_console ipywidgets widgetsnbextension ip
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for notebook widgetsnbextension urllib3 jupyter cryptography
# /
# -
# \
# Examining conflict for notebook jupyter_console ipywidgets widgetsnbextension ip
# |
# Examining conflict for notebook jupyter_console ipywidgets ipython widgetsnbexte
# /
# -
# \
# |
# /
# -
# Examining conflict for notebook widgetsnbextension jinja2 nbconvert jupyter:  27
# |
# /
# -
# Examining conflict for typing_extensions importlib-metadata spacy ipykernel thin
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for typing_extensions thinc importlib-metadata:  28%|▎| 59/21
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for gobject-introspection gtk2 xorg-libxpm graphviz xorg-libx
# \
# |
# Examining conflict for xorg-libxpm graphviz xorg-libxext xorg-xextproto cairo:
# Examining conflict for gobject-introspection gtk2 pyqt xorg-libxpm graphviz xorg
# \
# |
# /
# Examining conflict for xorg-libxpm graphviz xorg-libxext xorg-xproto cairo xorg-
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for numpy pandas matplotlib-base pytorch scipy scikit-learn s
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for pandas scipy scikit-learn spacy torchvision matplotlib li
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for numpy pandas matplotlib-base pytorch scipy scikit-learn s
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for numpy libgfortran5 blas pytorch libgfortran-ng scipy scik
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for numpy pandas matplotlib-base blas pytorch scipy scikit-le
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for numpy blas pytorch scipy scikit-learn liblapacke:  36%|▎|
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for numpy pytorch mkl scipy scikit-learn thinc libblas:  36%|
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for libblas numpy blas pytorch mkl scipy scikit-learn libgcc-
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for numpy pandas liblapack blas pytorch matplotlib-base scipy
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for numpy pandas liblapack blas pytorch matplotlib-base scipy
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for scikit-learn fastai threadpoolctl:  39%|▍| 81/210 [04:51<
# |
# /
# -
# \
# |
# /
# Examining conflict for scikit-learn fastai joblib:  40%|▍| 83/210 [04:52<08:58,
# \
# Examining conflict for spacy thinc fastai:  40%|▍| 84/210 [04:52<06:19,  3.01s/i
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for preshed spacy cymem thinc fastai:  42%|▍| 89/210 [05:02<0
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for preshed murmurhash spacy thinc fastai:  43%|▍| 90/210 [05
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for spacy fastai urllib3 requests:  43%|▍| 91/210 [05:06<04:5
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for spacy preshed thinc fastai:  44%|▍| 92/210 [05:07<04:04,
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for spacy thinc srsly fastai:  45%|▍| 94/210 [05:10<03:20,  1
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for pip fastcore python spacy wheel fastai:  45%|▍| 95/210 [0
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for spacy thinc wasabi fastai:  46%|▍| 96/210 [05:13<02:59,
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for prompt_toolkit jupyter_console ipython wcwidth spacy prom
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for testpath spacy pickleshare importlib_metadata ipython:  4
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for spacy fastai requests:  48%|▍| 100/210 [05:19<02:39,  1.4
# |
# /
# -
# \
# |
# Examining conflict for notebook pandas jupyter_console matplotlib-base python-da
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for jinja2 nbconvert markupsafe notebook:  50%|▍| 104/210 [05
# \
# |
# /
# -
# \
# Examining conflict for fastcore nbconvert bleach packaging fastai:  50%|▌| 106/2
# |
# Examining conflict for notebook jupyter_console ipykernel nbconvert entrypoints
# /
# -
# \
# |
# /
# Examining conflict for notebook nbconvert testpath jupyter:  51%|▌| 108/210 [05:
# -
# \
# Examining conflict for jupyterlab_pygments nbconvert notebook jupyter:  52%|▌| 1
# /
# -
# Examining conflict for notebook defusedxml nbconvert jupyter:  52%|▌| 110/210 [0
# \
# |
# Examining conflict for nbconvert bleach:  53%|▌| 111/210 [05:25<00:35,  2.82it/s
# /
# Examining conflict for notebook ipywidgets ipython jupyter_core attrs urllib3 tr
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for jupyterlab_pygments notebook prompt_toolkit jupyter_conso
# -
# \
# |
# /
# Examining conflict for decorator notebook jupyter_console ipywidgets ipython jup
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for nbconvert pandoc:  55%|▌| 115/210 [05:27<00:49,  1.93it/s
# /
# Examining conflict for notebook jupyter_console nest-asyncio ipykernel nbconvert
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for notebook nbconvert nbclient jupyter:  57%|▌| 120/210 [05:
# \
# |
# Examining conflict for gobject-introspection gtk2 pyqt graphviz harfbuzz qt cair
# /
# -
# \
# |
# Examining conflict for gtk2 pyqt xorg-libxpm graphviz gettext libglib gst-plugin
# /
# -
# \
# Examining conflict for gobject-introspection pillow gtk2 matplotlib-base pyqt fr
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for gobject-introspection gtk2 gts graphviz gettext libglib l
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for gobject-introspection gtk2 matplotlib-base pyqt graphviz
# /
# -
# \
# |
# /
# Examining conflict for notebook cffi urllib3 argon2-cffi fastai cryptography pyo
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for parso jedi ipython:  62%|▌| 130/210 [05:35<00:37,  2.11it
# -
# Examining conflict for jedi ipython:  62%|██▍ | 130/210 [05:35<00:37,  2.11it/s]
# \
# Examining conflict for prompt_toolkit jupyter_console ipywidgets ipykernel jupyt
# |
# /
# -
# \
# Examining conflict for prompt_toolkit jupyter_console ipywidgets ipython ipykern
# |
# /
# -
# Examining conflict for prompt_toolkit wcwidth backports.functools_lru_cache fast
# \
# |
# /
# -
# Examining conflict for wcwidth tornado entrypoints backports.functools_lru_cache
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for gobject-introspection gtk2 graphviz gdk-pixbuf harfbuzz c
# |
# /
# Examining conflict for gobject-introspection gtk2 gts xorg-libxpm graphviz gette
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for jupyter_console backcall ipywidgets ipykernel ipython:  7
# /
# -
# Examining conflict for jupyter_console ipywidgets pexpect ipykernel jupyter ipyt
# \
# |
# /
# -
# Examining conflict for notebook jupyter_console pexpect terminado ptyprocess ipy
# \
# |
# Examining conflict for ipykernel jupyter_console ipython ipywidgets:  71%|▋| 150
# -
# \
# Examining conflict for jupyter_console ipywidgets ipykernel pickleshare ipython:
# /
# -
# Examining conflict for libclang qt libllvm10:  72%|▋| 152/210 [05:41<00:18,  3.2
# \
# Examining conflict for qt nss pyqt:  72%|███▌ | 152/210 [05:41<00:18,  3.21it/s]
# |
# Examining conflict for libpq sqlite libedit nss krb5 python qt:  73%|▋| 154/210
# /
# Examining conflict for graphviz fonts-conda-ecosystem fonts-conda-forge:  76%|▊|
# Examining conflict for fastcore matplotlib-base pyparsing bleach packaging fasta
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for cudatoolkit torchvision pytorch fastai:  77%|▊| 162/210 [
# \
# |
# /
# -
# \
# |
# Examining conflict for gobject-introspection gtk2 graphviz harfbuzz cairo pixman
# /
# -
# \
# |
# Examining conflict for gobject-introspection gtk2 graphviz harfbuzz cairo xorg-l
# -
# Examining conflict for gobject-introspection graphviz xorg-libxau gst-plugins-ba
# \
# Examining conflict for gobject-introspection pthread-stubs graphviz gst-plugins-
# /
# -
# Examining conflict for gobject-introspection gtk2 xorg-libxpm graphviz xorg-libs
# \
# |
# Examining conflict for gobject-introspection graphviz gst-plugins-base xorg-libx
# /
# -
# \
# Examining conflict for pysocks urllib3 requests:  81%|▊| 171/210 [05:45<00:09,
# Examining conflict for xorg-renderproto xorg-libxrender graphviz cairo:  82%|▊|
# Examining conflict for pillow gtk2 matplotlib-base lcms2 libwebp graphviz gdk-pi
# -
# \
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for pillow gtk2 lcms2 libwebp graphviz gdk-pixbuf qt zstd lib
# |
# /
# Examining conflict for pillow gtk2 matplotlib-base pyqt lcms2 libwebp graphviz g
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for pillow gtk2 lcms2 libwebp graphviz libwebp-base gdk-pixbu
# Examining conflict for pillow gtk2 lcms2 libwebp graphviz libwebp-base gdk-pixbu
# -
# Examining conflict for notebook pyzmq qtconsole zeromq jupyter_client:  85%|▊| 1
# \
# |
# /
# Examining conflict for notebook pyzmq libsodium qtconsole zeromq jupyter_client:
# -
# \
# |
# Examining conflict for matplotlib fastai matplotlib-base kiwisolver:  86%|▊| 181
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for pillow matplotlib-base torchvision fastai matplotlib:  87
# /
# -
# \
# |
# /
# -
# Examining conflict for pillow matplotlib-base libwebp graphviz torchvision fasta
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for pillow torchvision matplotlib-base fastai:  89%|▉| 186/21
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for pillow matplotlib-base lcms2 torchvision fastai:  89%|▉|
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for pillow matplotlib-base torchvision fastai olefile:  90%|▉
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for qt libpq krb5:  90%|██▋| 189/210 [05:55<00:17,  1.22it/s]
# Examining conflict for qt mysql-common mysql-libs:  90%|▉| 189/210 [05:55<00:17,
# Examining conflict for importlib_metadata catalogue zipp importlib-metadata:  91
# -
# Examining conflict for gtk2 graphviz harfbuzz graphite2 pango:  91%|▉| 192/210 [
# \
# |
# Examining conflict for harfbuzz graphviz gtk2 pango:  92%|▉| 194/210 [05:55<00:0
# /
# -
# \
# Examining conflict for graphviz gtk2 pango:  94%|▉| 197/210 [05:55<00:02,  4.55i
# Examining conflict for graphviz gtk2 atk:  94%|▉| 197/210 [05:55<00:02,  4.55it/
# /
# Examining conflict for gstreamer qt gst-plugins-base pyqt:  95%|▉| 200/210 [05:5
# -
# Examining conflict for thinc catalogue srsly fastai:  96%|▉| 202/210 [05:56<00:0
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for notebook matplotlib-base ipykernel tornado terminado matp
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for cffi pycparser argon2-cffi cryptography brotlipy:  98%|▉|
# |
# Examining conflict for notebook jupyter_console ipywidgets ipykernel jupyter qtc
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for pyqt qt matplotlib qtconsole dbus: 100%|█| 210/210 [06:00
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for matplotlib qtconsole pyqt: : 211it [06:00,  1.75it/s]
# |
# /
# -
# \
# |
# /
# -
# Examining conflict for pyqt jupyter fastai matplotlib qtconsole: : 212it [06:01,  1.63it/s]
# \
# |
# /
# -
# \
# |
# /
# -
# \
# Examining conflict for qt pyqt mysql-libs: : 214it [06:02,  1.93it/s]
# |
# Examining conflict for pandas matplotlib fastai pytz: : 215it [06:02,  1.93it/s]
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# Examining conflict for torchvision pytorch fastai: : 218it [06:04,  1.94it/s]
# -
# Examining conflict for libxkbcommon qt pyqt: : 220it [06:04,  2.66it/s]
# |
# /
# -
# Examining conflict for qt gst-plugins-base pyqt: : 223it [06:04,  3.37it/s]
# \
# Examining conflict for libclang qt pyqt: : 225it [06:04,  4.31it/s]
# |
# Examining conflict for qt libpq pyqt: : 225it [06:04,  4.31it/s]
# /
# Examining conflict for matplotlib matplotlib-base fastai: : 227it [06:05,  5.27it/s]
# -
# \
# |
# /
# -
# \
# |
# Examining conflict for matplotlib matplotlib-base: : 230it [06:05,  4.81it/s]
# -
# \
# |
# /
# -
# Examining conflict for libuv fastai: : 231it [06:06,  3.27it/s]
# \
# Examining conflict for pyyaml fastai: : 232it [06:06,  3.88it/s]
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - backports.functools_lru_cache -> python[version='>=2.7,<2.8.0a0']
#
# Your python: python[version='>=3.6']
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with a past
# explicit spec that is not an explicit spec in this operation (pytorch):
#
#   - pytorch==1.6.0 -> python[version='>=3.8,<3.9.0a0'] -> pip
#   - torchvision==0.7.0 -> pillow[version='>=4.1.1']
#   - torchvision==0.7.0 -> python[version='>=3.7,<3.8.0a0'] -> pip
#   - torchvision==0.7.0 -> pytorch==1.6.0
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libgcc-ng conflicts for:
# graphite2 -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# matplotlib-base -> libgcc-ng[version='>=7.3.0|>=7.5.0|>=9.3.0']
# xorg-xproto -> libgcc-ng[version='>=7.3.0']
# joblib -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# nest-asyncio -> python[version='>=3.5'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libx11 -> libgcc-ng[version='>=7.5.0']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# fastprogress[version='>=0.1.22'] -> numpy[version='>=1.16.6,<2.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pyopenssl -> cryptography[version='>=2.8'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pyqt -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jupyter_console -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# chardet -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# scikit-learn -> scipy[version='>=0.19.1'] -> libgcc-ng[version='>=9.3.0']
# backcall -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# murmurhash -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xz -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# matplotlib -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# nbclient -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# nss -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# pandocfilters -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# notebook -> argon2-cffi -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# prompt_toolkit -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# readline -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# zlib -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# srsly -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0']
# pillow -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# nss -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.2.0']
# jinja2 -> markupsafe[version='>=2.0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# plac -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pyparsing -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# zeromq -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# matplotlib -> matplotlib-base[version='>=3.4.3,<3.4.4.0a0'] -> libgcc-ng[version='>=7.5.0|>=9.3.0']
# pthread-stubs -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# python_abi -> python=3.8 -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# xorg-libxpm -> gettext[version='>=0.19.8.1,<1.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.5.0']
# blas -> libgcc-ng[version='>=9.3.0']
# pytorch==1.6.0 -> blas=[build=mkl] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# pyrsistent -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# wasabi -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# matplotlib-base -> kiwisolver[version='>=1.0.1'] -> libgcc-ng[version='>=7.2.0']
# krb5 -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# srsly -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# xorg-renderproto -> libgcc-ng[version='>=7.3.0']
# libwebp -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# packaging -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cymem -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pycparser -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# preshed -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# certifi -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# thinc -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libxml2 -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# harfbuzz -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pexpect -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# tk -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cython-blis -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0']
# brotlipy -> cffi[version='>=1.0.0'] -> libgcc-ng[version='>=7.2.0']
# pandoc -> gmp -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pango -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jpeg -> libgcc-ng[version='>=7.2.0|>=7.5.0']
# backports.functools_lru_cache -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libxt -> xorg-libx11=1.6 -> libgcc-ng[version='>=7.5.0']
# wheel -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# qt -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# argon2-cffi -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# attrs -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libxext -> xorg-libx11=1.6 -> libgcc-ng[version='>=7.5.0']
# nbformat -> python[version='>=3.5'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libwebp-base -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# zipp -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# numpy -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# urllib3 -> brotlipy[version='>=0.6.0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libxrender -> xorg-libx11=1.6 -> libgcc-ng[version='>=7.5.0']
# mysql-libs -> libgcc-ng[version='>=7.5.0']
# qt -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libgcc-ng[version='>=9.3.0']
# qtpy -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# scipy -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# cairo -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# requests -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# ninja -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# typing_extensions -> python[version='>=3.5'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libxcb -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# gobject-introspection -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# tornado -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pyrsistent -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0']
# graphviz -> cairo[version='>=1.16.0,<1.17.0a0'] -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# pytz -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jupyterlab_pygments -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# lz4-c -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cudatoolkit -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libuv -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gtk2 -> atk-1.0[version='>=2.36.0'] -> libgcc-ng[version='>=7.2.0|>=7.5.0|>=9.3.0']
# pixman -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# expat -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyyaml -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# async_generator -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pcre -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# fribidi -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# send2trash -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libx11 -> libxcb=1 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# mistune -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libgcc-ng[version='>=9.3.0']
# decorator -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libpq -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# bleach -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# prompt-toolkit -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libxdmcp -> libgcc-ng[version='>=7.3.0']
# ipykernel -> debugpy[version='>=1,<2.0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jupyter_core -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libglib -> libgcc-ng[version='>=7.5.0']
# giflib -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# atk-1.0 -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# traitlets -> python[version='>=3.7'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libsodium -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# yaml -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libedit -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# defusedxml -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# entrypoints -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cryptography -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# scipy -> libopenblas[version='>=0.3.2,<0.3.3.0a0'] -> libgcc-ng[version='>=8.2.0']
# atk-1.0 -> gobject-introspection=1 -> libgcc-ng[version='>=7.2.0']
# scikit-learn -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# fastcore -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cython-blis -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# jupyter_client -> python[version='>=3.6.1'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# fontconfig -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-xextproto -> libgcc-ng[version='>=7.3.0']
# pygments -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libllvm10 -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=7.2.0']
# wcwidth -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libxpm -> libgcc-ng[version='>=7.3.0']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gettext -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libgcc-ng[version='>=9.3.0']
# catalogue -> python[version='>=3.6,<3.7.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# zstd -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libxau -> libgcc-ng[version='>=7.3.0']
# parso -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gettext -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libsm -> libgcc-ng[version='>=7.3.0']
# pandas -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gst-plugins-base -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libxrender -> libgcc-ng[version='>=7.3.0']
# olefile -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libclang -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# lcms2 -> jpeg[version='>=9b,<10a'] -> libgcc-ng[version='>=7.2.0']
# atk -> atk-1.0=2.36.0 -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# python-dateutil -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# ncurses -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# torchvision==0.7.0 -> numpy[version='>=1.11'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# icu -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# argon2-cffi -> cffi[version='>=1.0.0'] -> libgcc-ng[version='>=7.2.0']
# testpath -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# openssl -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# ptyprocess -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gdk-pixbuf -> gobject-introspection -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# dbus -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pyzmq -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libxkbcommon -> libgcc-ng[version='>=7.3.0']
# tqdm -> python[version='>=2.7'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libtiff -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# widgetsnbextension -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# kiwisolver -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# prometheus_client -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gdk-pixbuf -> libgcc-ng[version='>=7.5.0']
# libpng -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# brotlipy -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# xorg-libxext -> libgcc-ng[version='>=7.3.0']
# idna -> python[version='>=3.5'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# mysql-libs -> openssl[version='>=1.1.1g,<1.1.2a'] -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# nbconvert -> mistune[version='>=0.8.1,<2'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cffi -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gstreamer -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# gtk2 -> libgcc-ng[version='>=7.3.0']
# lcms2 -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# libglib -> gettext[version='>=0.19.8.1,<1.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# numpy -> libopenblas[version='>=0.3.2,<0.3.3.0a0'] -> libgcc-ng[version='>=8.2.0|>=9.3.0']
# nspr -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# gts -> libgcc-ng[version='>=7.5.0']
# ipython_genutils -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# six -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pango -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libgcc-ng[version='>=9.3.0']
# freetype -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libiconv -> libgcc-ng[version='>=7.2.0|>=7.5.0']
# pickleshare -> python[version='>=3'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-kbproto -> libgcc-ng[version='>=7.3.0']
# markupsafe -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# sqlite -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pip -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libllvm10 -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# qtconsole -> pyqt -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# xorg-libice -> libgcc-ng[version='>=7.3.0']
# xorg-libxt -> libgcc-ng[version='>=7.3.0']
# backports -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# graphviz -> libgcc-ng[version='>=7.2.0|>=7.5.0']
# cycler -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libuuid -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libtool -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# fastai -> matplotlib -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# libffi -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# spacy -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# ipywidgets -> python -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# threadpoolctl -> python[version='>=3.6'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# glib -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# libevent -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
#
# Package gstreamer conflicts for:
# qt -> gstreamer[version='>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0|>=1.14.4,<1.15.0a0']
# qt -> gst-plugins-base[version='>=1.14.4,<1.15.0a0'] -> gstreamer[version='>=1.12.2,<1.13.0a0|>=1.14.0,<2.0a0|>=1.14.5,<2.0a0']
# pyqt -> qt[version='>=5.12.9,<5.13.0a0'] -> gstreamer[version='>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0|>=1.14.4,<1.15.0a0']
# gst-plugins-base -> gstreamer[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.14.0,<2.0a0|>=1.14.5,<2.0a0|>=1.18.5,<2.0a0']
#
# Package libuuid conflicts for:
# zipp -> python[version='>=3.6'] -> libuuid[version='>=1.0.3,<2.0a0']
# plac -> python -> libuuid[version='>=1.0.3,<2.0a0']
# packaging -> python[version='>=3.6'] -> libuuid[version='>=1.0.3,<2.0a0']
# qtpy -> python -> libuuid[version='>=1.0.3,<2.0a0']
# ptyprocess -> python -> libuuid[version='>=1.0.3,<2.0a0']
# wheel -> python -> libuuid[version='>=1.0.3,<2.0a0']
# idna -> python[version='>=3.5'] -> libuuid[version='>=1.0.3,<2.0a0']
# fastcore -> python -> libuuid[version='>=1.0.3,<2.0a0']
# webencodings -> python -> libuuid[version='>=1.0.3,<2.0a0']
# decorator -> python -> libuuid[version='>=1.0.3,<2.0a0']
# prompt-toolkit -> python -> libuuid[version='>=1.0.3,<2.0a0']
# graphviz -> fontconfig[version='>=2.13.0,<3.0a0'] -> libuuid[version='>=2.32.1,<3.0a0']
# pytz -> python -> libuuid[version='>=1.0.3,<2.0a0']
# glib -> python= -> libuuid[version='>=1.0.3,<2.0a0']
# ipython_genutils -> python -> libuuid[version='>=1.0.3,<2.0a0']
# wcwidth -> python -> libuuid[version='>=1.0.3,<2.0a0']
# async_generator -> python[version='>2.7'] -> libuuid[version='>=1.0.3,<2.0a0']
# ipywidgets -> python -> libuuid[version='>=1.0.3,<2.0a0']
# ...
# numpy -> mkl_fft -> numpy-base[version='>=1.0.14,<2.0a0|>=1.0.6,<2.0a0|>=1.0.2,<2.0a0|>=1.0.4,<2.0a0']
#
# Package cytoolz conflicts for:
# spacy -> thinc[version='>=6.12.0,<6.13.0'] -> cytoolz[version='>=0.8,<0.9|>=0.9,<0.10|>=0.9.0,<0.10']
# thinc -> cytoolz[version='>=0.8,<0.9|>=0.9,<0.10|>=0.9.0,<0.10']
#
# Package markupsafe conflicts for:
# nbconvert -> jinja2[version='>=2.4'] -> markupsafe[version='>=0.23|>=2.0']
# jinja2 -> markupsafe[version='>=0.23|>=2.0']
# notebook -> jinja2 -> markupsafe[version='>=0.23|>=2.0']
#
# Package font-ttf-dejavu-sans-mono conflicts for:
# fonts-conda-forge -> font-ttf-dejavu-sans-mono
# fonts-conda-ecosystem -> fonts-anaconda -> font-ttf-dejavu-sans-mono
#
# Package graphite2 conflicts for:
# pango -> harfbuzz[version='>=2.4.0,<3.0a0'] -> graphite2[version='1.3.*|>=1.3.10,<2.0a0']
# harfbuzz -> graphite2[version='1.3.*|>=1.3.10,<2.0a0|>=1.3.11,<2.0a0|>=1.3.13,<2.0a0|>=1.3.14,<2.0a0']
# gtk2 -> harfbuzz[version='>=2.4.0,<3.0a0'] -> graphite2[version='>=1.3.12,<2.0a0|>=1.3.13,<2.0a0|>=1.3.14,<2.0a0']
# pango -> graphite2[version='>=1.3.11,<2.0a0|>=1.3.12,<2.0a0|>=1.3.13,<2.0a0|>=1.3.14,<2.0a0']
# graphviz -> graphite2[version='>=1.3.11,<2.0a0']
# graphviz -> gtk2 -> graphite2[version='>=1.3.10,<2.0a0|>=1.3.12,<2.0a0|>=1.3.13,<2.0a0|>=1.3.14,<2.0a0']
# gtk2 -> graphite2
#
# Package tqdm conflicts for:
# spacy -> tqdm[version='>=4.38.0,<5.0.0']
# spacy -> thinc[version='>=7.4.1'] -> tqdm[version='>=4.10.0,<5.0.0']
# fastai -> spacy -> tqdm[version='>=4.38.0,<5.0.0']
# thinc -> tqdm[version='>=4.10.0,<5.0.0']
#
# Package srsly conflicts for:
# spacy -> thinc[version='>=7.4.1'] -> srsly[version='>=0.0.6,<1.1.0|>=2.0.0,<3.0.0']
# thinc -> srsly[version='>=0.0.6,<1.1.0|>=2.0.0,<3.0.0']
# spacy -> srsly[version='>=1.0.2,<1.1.0']
# fastai -> spacy -> srsly[version='>=1.0.2,<1.1.0']
#
# Package jupyterlab_pygments conflicts for:
# jupyter -> nbconvert -> jupyterlab_pygments
# notebook -> nbconvert -> jupyterlab_pygments
# nbconvert -> jupyterlab_pygments
#
# Package jaraco.itertools conflicts for:
# zipp -> jaraco.itertools
# importlib_metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# catalogue -> zipp[version='>=0.5'] -> jaraco.itertools
#
# Package zope.interface conflicts for:
# attrs -> zope.interface
# prometheus_client -> twisted -> zope.interface[version='>=4.0.2|>=4.4.2']
#
# Package libclang conflicts for:
# qt -> libclang[version='>=10.0.1,<11.0a0']
# pyqt -> qt[version='>=5.12.9,<5.13.0a0'] -> libclang[version='>=10.0.1,<11.0a0']
#
# Package krb5 conflicts for:
# qt -> libpq[version='>=12.3,<13.0a0'] -> krb5[version='>=1.17.1,<1.18.0a0']
# libpq -> krb5[version='>=1.14.2,<1.15.0a0|>=1.16,<1.17.0a0|>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.19.1,<1.20.0a0']
#
# Package threadpoolctl conflicts for:
# fastai -> scikit-learn -> threadpoolctl[version='>=2.0.0']
# scikit-learn -> threadpoolctl[version='>=2.0.0']
#
# Package brotlipy conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
# urllib3 -> brotlipy[version='>=0.6.0']
#
# Package sip conflicts for:
# pyqt -> sip[version='4.18.*|4.19.13.*|>=4.19.13,<=4.19.14|>=4.19.4,<=4.19.8']
# matplotlib -> pyqt -> sip[version='4.18.*|4.19.13.*|>=4.19.13,<=4.19.14|>=4.19.4,<=4.19.8']
# qtconsole -> pyqt -> sip[version='4.18.*|4.19.13.*|>=4.19.13,<=4.19.14|>=4.19.4,<=4.19.8']
#
# Package fonts-conda-forge conflicts for:
# graphviz -> fonts-conda-ecosystem -> fonts-conda-forge
# fonts-conda-ecosystem -> fonts-conda-forge
#
# Package libpq conflicts for:
# qt -> libpq[version='>=12.3,<13.0a0']
# pyqt -> qt[version='>=5.12.9,<5.13.0a0'] -> libpq[version='>=12.3,<13.0a0']
#
# Package matplotlib-base conflicts for:
# matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.3,<3.3.4.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0',build='py37hef1b27d_1|py38hef1b27d_1|py38hef1b27d_0|py36hef1b27d_0|py37hef1b27d_0|py36hef1b27d_1']
# fastai -> matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.3,<3.3.4.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0',build='py37hef1b27d_1|py38hef1b27d_1|py38hef1b27d_0|py36hef1b27d_0|py37hef1b27d_0|py36hef1b27d_1']
#
# Package atk conflicts for:
# graphviz -> gtk2 -> atk
# gtk2 -> atk
#
# Package notebook conflicts for:
# jupyter -> notebook
# widgetsnbextension -> notebook[version='>=4.4.1']
# ipywidgets -> widgetsnbextension[version='>=3.5.0,<3.6.0'] -> notebook[version='>=4.4.1']
#
# Package terminado conflicts for:
# widgetsnbextension -> notebook[version='>=4.4.1'] -> terminado[version='>=0.3.3|>=0.8.1|>=0.8.3']
# notebook -> terminado[version='>=0.3.3|>=0.8.1|>=0.8.3']
# jupyter -> notebook -> terminado[version='>=0.3.3|>=0.8.1|>=0.8.3']
#
# Package font-ttf-inconsolata conflicts for:
# fonts-conda-ecosystem -> fonts-anaconda -> font-ttf-inconsolata
# fonts-conda-forge -> font-ttf-inconsolata
#
# Package pysocks conflicts for:
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package pytorch conflicts for:
# fastai -> torchvision[version='>=0.8'] -> pytorch[version='1.10.0|1.9.1|1.9.0|1.8.1|1.8.0|1.7.1|1.7.0|1.7.1.*']
# fastai -> pytorch[version='>=1.7.0']
#
# Package widgetsnbextension conflicts for:
# jupyter -> ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
# ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.23=0
#   - feature:|@/linux-64::__glibc==2.23=0
#   - argon2-cffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - atk-1.0 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - blas -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - brotlipy -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cairo -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - cffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - cryptography -> libgcc-ng -> __glibc[version='>=2.17']
#   - cudatoolkit -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cymem -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cython-blis -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - dbus -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - expat -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - fontconfig -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - freetype -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - fribidi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gdk-pixbuf -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gettext -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - giflib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - glib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gobject-introspection -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - graphite2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - graphviz -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gst-plugins-base -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gstreamer -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gtk2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - gts -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - harfbuzz -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - icu -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - jpeg -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - kiwisolver -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - krb5 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - lcms2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libclang -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libedit -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libevent -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libgfortran-ng -> __glibc[version='>=2.17']
#   - libglib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libiconv -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libllvm10 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libpng -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libpq -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libsodium -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtiff -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libtool -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libuv -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libwebp -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libwebp-base -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libxcb -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libxkbcommon -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lz4-c -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - markupsafe -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib-base -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - mistune -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - murmurhash -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - mysql-libs -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - ncurses -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - ninja -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - nspr -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - nss -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - numpy -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - openssl -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pandas -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pango -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pcre -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pillow -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pixman -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - preshed -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pthread-stubs -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pyqt -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pyrsistent -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - python[version='>=3.6'] -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pyyaml -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pyzmq -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - qt -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - readline -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - scikit-learn -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - scipy -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - spacy -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - sqlite -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - srsly -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - thinc -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tk -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - tornado -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-kbproto -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libice -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libsm -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libx11 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - xorg-libxau -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxdmcp -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxext -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxpm -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxrender -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxt -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-renderproto -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-xextproto -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-xproto -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xz -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zeromq -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zlib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.23
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastai==2.0.11
# Out:
# Collecting fastai==2.0.11
#   Downloading fastai-2.0.11-py3-none-any.whl (354 kB)
#      |████████████████████████████████| 354 kB 25.2 MB/s
# Requirement already satisfied: pip in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (20.2.4)
# Requirement already satisfied: spacy in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (2.3.2)
# Requirement already satisfied: requests in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (2.25.0)
# Requirement already satisfied: pandas in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (1.1.4)
# Requirement already satisfied: packaging in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (20.4)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (1.7.0)
# Requirement already satisfied: fastcore>=1.0.5 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (1.3.6)
# Requirement already satisfied: pillow in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (8.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (1.0.0)
# Requirement already satisfied: scikit-learn in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (0.23.2)
# Requirement already satisfied: scipy in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (1.5.3)
# Requirement already satisfied: pyyaml in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (5.3.1)
# Requirement already satisfied: matplotlib in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (3.3.3)
# Requirement already satisfied: torchvision>=0.7 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from fastai==2.0.11) (0.8.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (2.0.4)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (0.4.1)
# Requirement already satisfied: setuptools in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (49.6.0.post20201009)
# Requirement already satisfied: thinc==7.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (7.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (1.19.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (0.9.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (3.0.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from spacy->fastai==2.0.11) (4.52.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests->fastai==2.0.11) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests->fastai==2.0.11) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests->fastai==2.0.11) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests->fastai==2.0.11) (2020.11.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from pandas->fastai==2.0.11) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from pandas->fastai==2.0.11) (2020.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from packaging->fastai==2.0.11) (2.4.7)
# Requirement already satisfied: six in /opt/conda/envs/fastai/lib/python3.8/site-packages (from packaging->fastai==2.0.11) (1.15.0)
# Requirement already satisfied: future in /opt/conda/envs/fastai/lib/python3.8/site-packages (from torch>=1.6.0->fastai==2.0.11) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/envs/fastai/lib/python3.8/site-packages (from torch>=1.6.0->fastai==2.0.11) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/envs/fastai/lib/python3.8/site-packages (from torch>=1.6.0->fastai==2.0.11) (0.6)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from scikit-learn->fastai==2.0.11) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from scikit-learn->fastai==2.0.11) (2.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from matplotlib->fastai==2.0.11) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from matplotlib->fastai==2.0.11) (1.3.1)
# Installing collected packages: fastai
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.1.5
#     Uninstalling fastai-2.1.5:
#       Successfully uninstalled fastai-2.1.5
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# fastbook 0.0.14 requires fastai>=2.1, but you'll have fastai 2.0.11 which is incompatible.
# Successfully installed fastai-2.0.11
# Note: you may need to restart the kernel to use updated packages.

# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/download.jpeg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…
